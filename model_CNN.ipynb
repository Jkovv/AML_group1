# %%
import os
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms
from datasets import load_from_disk
from PIL import Image
import pandas as pd

torch.manual_seed(42)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)
# Out:
# Using device: cpu

# %%
dataset = load_from_disk("processed_bird_data")
train_ds = dataset["train"]
val_ds   = dataset["validation"]

print("Train samples:", len(train_ds))
print("Val samples:  ", len(val_ds))
# Out:
# Train samples: 3337
# Val samples:   589

# %%
class BirdsTrainValDataset(Dataset):
    def __init__(self, hf_dataset, augment=False):
        self.ds = hf_dataset
        if augment:
            self.transform = transforms.Compose([
                transforms.Resize((224, 224)),
                transforms.RandomHorizontalFlip(),
                transforms.RandomRotation(15),
                transforms.ToTensor(),
            ])
        else:
            self.transform = transforms.Compose([
                transforms.Resize((224, 224)),
                transforms.ToTensor(),
            ])

    def __len__(self):
        return len(self.ds)

    def __getitem__(self, idx):
        sample = self.ds[idx]
        img = sample["image"] #todo: check rezi's notebook
        label = int(sample["label"])

        img = self.transform(img)
        return img, label

# %%
BATCH_SIZE = 64

train_loader = DataLoader(
    BirdsTrainValDataset(train_ds, augment=True),
    batch_size=BATCH_SIZE,
    shuffle=True
)

val_loader = DataLoader(
    BirdsTrainValDataset(val_ds, augment=False),
    batch_size=BATCH_SIZE,
    shuffle=False
)

print("Train batches:", len(train_loader))
print("Val batches:  ", len(val_loader))
# Out:
# Train batches: 53
# Val batches:   10

# %%
NUM_CLASSES = 200

class BirdCNN(nn.Module):
    def __init__(self, num_classes=NUM_CLASSES):
        super().__init__()

        self.features = nn.Sequential(
            nn.Conv2d(3, 32, kernel_size=5, stride=1, padding=2),
            nn.BatchNorm2d(32),
            nn.ReLU(),
            nn.MaxPool2d(2), #112x112

            nn.Conv2d(32, 64, kernel_size=3, padding=1),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.MaxPool2d(2), #56x56

            nn.Conv2d(64, 128, kernel_size=3, padding=1),
            nn.BatchNorm2d(128),
            nn.ReLU(),
            nn.MaxPool2d(2), #28x28

            nn.Conv2d(128, 256, kernel_size=3, padding=1),
            nn.BatchNorm2d(256),
            nn.ReLU(),
            nn.MaxPool2d(2), #14x14

            nn.AdaptiveAvgPool2d((1,1)) #256-dim vector
        )

        self.dropout = nn.Dropout(0.2)

        self.classifier = nn.Sequential(
            nn.Linear(256, 256),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(256, num_classes)
        )

    def forward(self, x):
        feat = self.features(x) #[B,256,1,1]
        feat = feat.view(feat.size(0), -1) #[B,256]
        feat = self.dropout(feat)
        logits = self.classifier(feat)
        return logits

model = BirdCNN().to(device)
print(model)
# Out:
# BirdCNN(
#   (features): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (4): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (5): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (8): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (10): ReLU()
#     (11): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (12): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (14): ReLU()
#     (15): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (16): AdaptiveAvgPool2d(output_size=(1, 1))
#   )
#   (dropout): Dropout(p=0.2, inplace=False)
#   (classifier): Sequential(
#     (0): Linear(in_features=256, out_features=256, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.2, inplace=False)
#     (3): Linear(in_features=256, out_features=200, bias=True)
#   )
# )

# %%
EPOCHS = 40
criterion = nn.CrossEntropyLoss()

optimizer = optim.Adam(
    model.parameters(),
    lr=1e-3,
    weight_decay=1e-4 #L2 regularization
)

scheduler = optim.lr_scheduler.CosineAnnealingLR(
    optimizer,
    T_max=EPOCHS 
)

# %%
def train_one_epoch(epoch):
    model.train()
    total_loss = 0
    correct = 0
    samples = 0

    for batch_idx, (images, labels) in enumerate(train_loader):
        images, labels = images.to(device), labels.to(device)

        optimizer.zero_grad()
        outputs = model(images)
        loss = criterion(outputs, labels)

        loss.backward()
        optimizer.step()

        total_loss += loss.item() * labels.size(0)

        preds = outputs.argmax(dim=1)
        correct += (preds == labels).sum().item()
        samples += labels.size(0)

        # Logging batch
        if batch_idx % 20 == 0:
            print(f"[Epoch {epoch}] Batch {batch_idx}/{len(train_loader)} | loss={loss.item():.4f}")

    avg_loss = total_loss / samples
    acc = correct / samples

    return avg_loss, acc

# %%
def evaluate(epoch):
    model.eval()
    total_loss = 0
    correct = 0
    samples = 0

    with torch.no_grad():
        for batch_idx, (images, labels) in enumerate(val_loader):
            images, labels = images.to(device), labels.to(device)

            outputs = model(images)
            loss = criterion(outputs, labels)

            total_loss += loss.item() * labels.size(0)

            preds = outputs.argmax(dim=1)
            correct += (preds == labels).sum().item()
            samples += labels.size(0)

    avg_loss = total_loss / samples
    acc = correct / samples

    return avg_loss, acc

# %%
best_val_acc = 0.0

for epoch in range(1, EPOCHS + 1):
    print(f"\nEpoch {epoch}/{EPOCHS}")

    train_loss, train_acc = train_one_epoch(epoch)
    val_loss, val_acc = evaluate(epoch)

    scheduler.step()

    print(f"Train: loss={train_loss:.4f}, acc={train_acc:.4f}")
    print(f"Val:   loss={val_loss:.4f}, acc={val_acc:.4f}")

    if val_acc > best_val_acc:
        best_val_acc = val_acc
        torch.save(model.state_dict(), "resnet_best_model.pth")
        print("Best CNN model saved")
# Out:
# Epoch 1/40
# [Epoch 1] Batch 0/53 | loss=4.7632
# [Epoch 1] Batch 20/53 | loss=4.7605
# [Epoch 1] Batch 40/53 | loss=4.7570
# Train: loss=4.7882, acc=0.0363
# Val:   loss=5.0873, acc=0.0255
# Best CNN model saved
#
# Epoch 2/40
# [Epoch 2] Batch 0/53 | loss=4.8207
# [Epoch 2] Batch 20/53 | loss=4.6825
# [Epoch 2] Batch 40/53 | loss=4.6923
# Train: loss=4.7274, acc=0.0345
# Val:   loss=5.0293, acc=0.0204
#
# Epoch 3/40
# [Epoch 3] Batch 0/53 | loss=4.5023
# [Epoch 3] Batch 20/53 | loss=4.6127
# [Epoch 3] Batch 40/53 | loss=4.7283
# Train: loss=4.6312, acc=0.0414
# Val:   loss=4.9445, acc=0.0238
#
# Epoch 4/40
# [Epoch 4] Batch 0/53 | loss=4.5365
# [Epoch 4] Batch 20/53 | loss=4.6035
# [Epoch 4] Batch 40/53 | loss=4.4237
# Train: loss=4.5817, acc=0.0447
# Val:   loss=5.2904, acc=0.0170
#
# Epoch 5/40
# [Epoch 5] Batch 0/53 | loss=4.4648
# [Epoch 5] Batch 20/53 | loss=4.5346
# [Epoch 5] Batch 40/53 | loss=4.3814
# Train: loss=4.5270, acc=0.0515
# Val:   loss=4.8707, acc=0.0374
# Best CNN model saved
#
# Epoch 6/40
# [Epoch 6] Batch 0/53 | loss=4.4825
# [Epoch 6] Batch 20/53 | loss=4.4662
# [Epoch 6] Batch 40/53 | loss=4.4550
# Train: loss=4.4898, acc=0.0533
# Val:   loss=4.8483, acc=0.0323
#
# Epoch 7/40
# [Epoch 7] Batch 0/53 | loss=4.4877
# [Epoch 7] Batch 20/53 | loss=4.5089
# [Epoch 7] Batch 40/53 | loss=4.6179
# Train: loss=4.4266, acc=0.0581
# Val:   loss=4.8880, acc=0.0289
#
# Epoch 8/40
# [Epoch 8] Batch 0/53 | loss=4.3695
# [Epoch 8] Batch 20/53 | loss=4.4132
# [Epoch 8] Batch 40/53 | loss=4.2777
# Train: loss=4.3916, acc=0.0608
# Val:   loss=4.8544, acc=0.0492
# Best CNN model saved
#
# Epoch 9/40
# [Epoch 9] Batch 0/53 | loss=4.3256
# [Epoch 9] Batch 20/53 | loss=4.2649
# [Epoch 9] Batch 40/53 | loss=4.6491
# Train: loss=4.3282, acc=0.0677
# Val:   loss=4.9572, acc=0.0374
#
# Epoch 10/40
# [Epoch 10] Batch 0/53 | loss=4.0426
# [Epoch 10] Batch 20/53 | loss=4.1402
# [Epoch 10] Batch 40/53 | loss=4.3260
# Train: loss=4.2878, acc=0.0764
# Val:   loss=4.8044, acc=0.0492
#
# Epoch 11/40
# [Epoch 11] Batch 0/53 | loss=4.3608
# [Epoch 11] Batch 20/53 | loss=4.1823
# [Epoch 11] Batch 40/53 | loss=4.3314
# Train: loss=4.2373, acc=0.0788
# Val:   loss=4.7923, acc=0.0475
#
# Epoch 12/40
# [Epoch 12] Batch 0/53 | loss=3.9750
# [Epoch 12] Batch 20/53 | loss=4.2938
# [Epoch 12] Batch 40/53 | loss=3.8570
# Train: loss=4.1952, acc=0.0830
# Val:   loss=4.7921, acc=0.0679
# Best CNN model saved
#
# Epoch 13/40
# [Epoch 13] Batch 0/53 | loss=4.2545
# [Epoch 13] Batch 20/53 | loss=4.1435
# [Epoch 13] Batch 40/53 | loss=4.2841
# Train: loss=4.1427, acc=0.0893
# Val:   loss=4.8261, acc=0.0577
#
# Epoch 14/40
# [Epoch 14] Batch 0/53 | loss=3.8848
# [Epoch 14] Batch 20/53 | loss=4.0725
# [Epoch 14] Batch 40/53 | loss=4.2355
# Train: loss=4.0780, acc=0.0950
# Val:   loss=4.9316, acc=0.0492
#
# Epoch 15/40
# [Epoch 15] Batch 0/53 | loss=3.8976
# [Epoch 15] Batch 20/53 | loss=3.8915
# [Epoch 15] Batch 40/53 | loss=4.2761
# Train: loss=4.0417, acc=0.1052
# Val:   loss=4.9895, acc=0.0407
#
# Epoch 16/40
# [Epoch 16] Batch 0/53 | loss=3.8700
# [Epoch 16] Batch 20/53 | loss=4.1553
# [Epoch 16] Batch 40/53 | loss=3.8586
# Train: loss=4.0109, acc=0.1037
# Val:   loss=4.7556, acc=0.0560
#
# Epoch 17/40
# [Epoch 17] Batch 0/53 | loss=3.8876
# [Epoch 17] Batch 20/53 | loss=3.8786
# [Epoch 17] Batch 40/53 | loss=4.0317
# Train: loss=3.9620, acc=0.1124
# Val:   loss=4.7858, acc=0.0543
#
# Epoch 18/40
# [Epoch 18] Batch 0/53 | loss=3.9198
# [Epoch 18] Batch 20/53 | loss=4.0569
# [Epoch 18] Batch 40/53 | loss=3.6146
# Train: loss=3.9162, acc=0.1079
# Val:   loss=4.8097, acc=0.0679
#
# Epoch 19/40
# [Epoch 19] Batch 0/53 | loss=3.6271
# [Epoch 19] Batch 20/53 | loss=3.9220
# [Epoch 19] Batch 40/53 | loss=3.9688
# Train: loss=3.8753, acc=0.1148
# Val:   loss=4.8617, acc=0.0679
#
# Epoch 20/40
# [Epoch 20] Batch 0/53 | loss=3.9133
# [Epoch 20] Batch 20/53 | loss=3.9325
# [Epoch 20] Batch 40/53 | loss=3.7767
# Train: loss=3.8590, acc=0.1208
# Val:   loss=4.7529, acc=0.0662
#
# Epoch 21/40
# [Epoch 21] Batch 0/53 | loss=3.7473
# [Epoch 21] Batch 20/53 | loss=3.5555
# [Epoch 21] Batch 40/53 | loss=3.6969
# Train: loss=3.8177, acc=0.1196
# Val:   loss=4.7692, acc=0.0662
#
# Epoch 22/40
# [Epoch 22] Batch 0/53 | loss=3.5189
# [Epoch 22] Batch 20/53 | loss=3.7353
# [Epoch 22] Batch 40/53 | loss=3.8289
# Train: loss=3.7840, acc=0.1190
# Val:   loss=4.6719, acc=0.0696
# Best CNN model saved
#
# Epoch 23/40
# [Epoch 23] Batch 0/53 | loss=3.8770
# [Epoch 23] Batch 20/53 | loss=3.9274
# [Epoch 23] Batch 40/53 | loss=3.8011
# Train: loss=3.7561, acc=0.1307
# Val:   loss=4.7102, acc=0.0679
#
# Epoch 24/40
# [Epoch 24] Batch 0/53 | loss=3.8275
# [Epoch 24] Batch 20/53 | loss=3.8936
# [Epoch 24] Batch 40/53 | loss=3.9067
# Train: loss=3.7191, acc=0.1369
# Val:   loss=4.7458, acc=0.0730
# Best CNN model saved
#
# Epoch 25/40
# [Epoch 25] Batch 0/53 | loss=3.9903
# [Epoch 25] Batch 20/53 | loss=3.6792
# [Epoch 25] Batch 40/53 | loss=3.7839
# Train: loss=3.7081, acc=0.1358
# Val:   loss=4.7142, acc=0.0798
# Best CNN model saved
#
# Epoch 26/40
# [Epoch 26] Batch 0/53 | loss=3.5107
# [Epoch 26] Batch 20/53 | loss=3.5524
# [Epoch 26] Batch 40/53 | loss=3.7908
# Train: loss=3.6930, acc=0.1366
# Val:   loss=4.6736, acc=0.0611
#
# Epoch 27/40
# [Epoch 27] Batch 0/53 | loss=3.7581
# [Epoch 27] Batch 20/53 | loss=3.6459
# [Epoch 27] Batch 40/53 | loss=3.6027
# Train: loss=3.6616, acc=0.1435
# Val:   loss=4.7236, acc=0.0747
#
# Epoch 28/40
# [Epoch 28] Batch 0/53 | loss=3.6689
# [Epoch 28] Batch 20/53 | loss=3.6568
# [Epoch 28] Batch 40/53 | loss=3.5034
# Train: loss=3.6278, acc=0.1495
# Val:   loss=4.7024, acc=0.0645
#
# Epoch 29/40
# [Epoch 29] Batch 0/53 | loss=3.6362
# [Epoch 29] Batch 20/53 | loss=3.5665
# [Epoch 29] Batch 40/53 | loss=3.4351
# Train: loss=3.6041, acc=0.1495
# Val:   loss=4.7026, acc=0.0747
#
# Epoch 30/40
# [Epoch 30] Batch 0/53 | loss=3.3157
# [Epoch 30] Batch 20/53 | loss=3.5842
# [Epoch 30] Batch 40/53 | loss=3.7456
# Train: loss=3.5865, acc=0.1531
# Val:   loss=4.6811, acc=0.0679
#
# Epoch 31/40
# [Epoch 31] Batch 0/53 | loss=3.5376
# [Epoch 31] Batch 20/53 | loss=3.4646
# [Epoch 31] Batch 40/53 | loss=3.6200
# Train: loss=3.5950, acc=0.1534
# Val:   loss=4.6866, acc=0.0679
#
# Epoch 32/40
# [Epoch 32] Batch 0/53 | loss=3.3812
# [Epoch 32] Batch 20/53 | loss=3.5682
# [Epoch 32] Batch 40/53 | loss=3.5506
# Train: loss=3.5756, acc=0.1600
# Val:   loss=4.6802, acc=0.0713
#
# Epoch 33/40
# [Epoch 33] Batch 0/53 | loss=3.4151
# [Epoch 33] Batch 20/53 | loss=3.3505
# [Epoch 33] Batch 40/53 | loss=3.4858
# Train: loss=3.5531, acc=0.1585
# Val:   loss=4.6873, acc=0.0662
#
# Epoch 34/40
# [Epoch 34] Batch 0/53 | loss=3.7414
# [Epoch 34] Batch 20/53 | loss=3.4926
# [Epoch 34] Batch 40/53 | loss=3.5255
# Train: loss=3.5616, acc=0.1525
# Val:   loss=4.6858, acc=0.0645
#
# Epoch 35/40
# [Epoch 35] Batch 0/53 | loss=3.5949
# [Epoch 35] Batch 20/53 | loss=3.3320
# [Epoch 35] Batch 40/53 | loss=3.2794
# Train: loss=3.5659, acc=0.1540
# Val:   loss=4.6873, acc=0.0713
#
# Epoch 36/40
# [Epoch 36] Batch 0/53 | loss=3.5480
# [Epoch 36] Batch 20/53 | loss=3.7754
# [Epoch 36] Batch 40/53 | loss=3.5322
# Train: loss=3.5463, acc=0.1585
# Val:   loss=4.6906, acc=0.0645
#
# Epoch 37/40
# [Epoch 37] Batch 0/53 | loss=3.9542
# [Epoch 37] Batch 20/53 | loss=3.4274
# [Epoch 37] Batch 40/53 | loss=3.4451
# Train: loss=3.5166, acc=0.1669
# Val:   loss=4.6922, acc=0.0662
#
# Epoch 38/40
# [Epoch 38] Batch 0/53 | loss=3.6461
# [Epoch 38] Batch 20/53 | loss=3.7385
# [Epoch 38] Batch 40/53 | loss=3.6345
# Train: loss=3.5463, acc=0.1618
# Val:   loss=4.6938, acc=0.0662
#
# Epoch 39/40
# [Epoch 39] Batch 0/53 | loss=3.5063
# [Epoch 39] Batch 20/53 | loss=3.3198
# [Epoch 39] Batch 40/53 | loss=3.5057
# Train: loss=3.5372, acc=0.1657
# Val:   loss=4.6851, acc=0.0679
#
# Epoch 40/40
# [Epoch 40] Batch 0/53 | loss=3.5650
# [Epoch 40] Batch 20/53 | loss=3.4738
# [Epoch 40] Batch 40/53 | loss=3.5719
# Train: loss=3.5325, acc=0.1642
# Val:   loss=4.6963, acc=0.0696

# %%
# todo: test data
